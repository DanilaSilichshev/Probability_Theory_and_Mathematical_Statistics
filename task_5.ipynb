# %% [markdown]
# <h1 align="center">Урок 5. Проверка статистических гипотез. P-значения. Доверительные интервалы. A/B-тестирование</h1>

# %%
import numpy as np
import scipy.stats as stats

# %% [markdown]
# 1. Известно, что генеральная совокупность распределена нормально
# со средним квадратическим отклонением, равным 16.
# Найти доверительный интервал для оценки математического ожидания a с надежностью 0.95,
# если выборочная средняя M = 80, а объем выборки n = 256.

# %% [markdown]
# $$ \overline{X} \pm Z_{\frac{\alpha}{2}}\frac{\sigma}{\sqrt{n}} = 80 \pm 1.96 \frac{16}{\sqrt{256}} = 80 \pm 1.96\ либо\ [78.04; 81.96]$$

# %% [markdown]
# 2. В результате 10 независимых измерений некоторой величины X, выполненных с одинаковой точностью,
# получены опытные данные:
# 6.9, 6.1, 6.2, 6.8, 7.5, 6.3, 6.4, 6.9, 6.7, 6.1
# Предполагая, что результаты измерений подчинены нормальному закону распределения вероятностей,
# оценить истинное значение величины X при помощи доверительного интервала, покрывающего это
# значение с доверительной вероятностью 0,95.

# %% [markdown]
# $ В\ данном\ случае\ применяем\ t-критерий\ (\sigma\ генеральной\ совокупности\ неизвестна):$
#
# $$ \overline{x} \pm t_{\frac{\alpha}{2}}\frac{sd}{\sqrt{n}} = \frac{\displaystyle\sum_{i=1}^{n}x_i}{n} \pm t_{\frac{\alpha}{2}}\frac{\sqrt\frac{\displaystyle\sum_{i=1}^{n}(x_i-\overline{x})^2}{n-1}}{\sqrt{n}}$$

# %%
measurements = np.array([6.9, 6.1, 6.2, 6.8, 7.5, 6.3, 6.4, 6.9, 6.7, 6.1])
measurements_mean, measurements_sd = round(np.mean(measurements), 2), np.std(measurements, ddof=1)
print(f"Математическое ожидание: {measurements_mean},\nнесмещённая оценка стандартного отклонения: {measurements_sd}")
# Out:
# Математическое ожидание: 6.59,
# несмещённая оценка стандартного отклонения: 0.4508017549014448

# %%
t = 2.262
print(f"Нижняя граница доверительного интервала: {measurements_mean - t * measurements_sd / np.sqrt(len(measurements))}, " 
      f"верхняя: {measurements_mean + t * measurements_sd / np.sqrt(len(measurements))}")
# Out:
# Нижняя граница доверительного интервала: 6.2675382559124255, верхняя: 6.912461744087574

# %% [markdown]
# 3. Проведтите тест гипотезы. Утверждается, что шарики для подшипников, изготовленные автоматическим станком, имеют средний диаметр 17 мм.
# Используя односторонний критерий с α=0,05, проверить эту гипотезу, если в выборке из n=100 шариков средний диаметр
# оказался равным 17.5 мм, а дисперсия известна и равна 4 кв. мм.

# %% [markdown]
# $ 1)\ Формулирование\ нулевой\ и\ альтернативной\ гипотез: $
#
# $ H_0: \mu=\mu_0 $
#
# $ H_1: \mu>\mu_0$
#
# $ 2)\ Выбор\ значения\ уровня\ статистической\ значимости:$
#
# $ \alpha = 0.05$
#
# $ 3)\ Выбор\ статистического\ теста\ (критерия):$
#
# $ Дисперсия\ известна\ =>\ используем\ Z-критерий$
#
# $ 4)\ Расчёт\ наблюдаемого\ критерия:$
#
# $ Z_н = \frac{\overline{x}-\mu}{\sigma\ /\sqrt{n}} = \frac{17.5-17}{0.2} = 2.5$
#
# $ 5)\ Сравнение\ наблюдаемого\ и\ табличного\ значения:$
#
# $ Z_т = 1.65\ при\ \alpha = 0.05, => Z_т < Z_н$
#
# $ 6)\ Вывод:\$
#
# $ Отвергаем\ нулевую\ гипотезу\ о\ равенстве\ средних$

# %% [markdown]
# 4. Проведите тест гипотезы. Продавец утверждает, что средний вес пачки печенья составляет 200 г.
# Из партии извлечена выборка из 10 пачек. Вес каждой пачки составляет:
# 202, 203, 199, 197, 195, 201, 200, 204, 194, 190.
# Известно, что их веса распределены нормально.
# Верно ли утверждение продавца, если учитывать, что доверительная вероятность равна 99%? (Провести двусторонний тест.)

# %% [markdown]
# $ Используем\ t-test,\ так\ как\ дисперсия\ неизвестна: $

# %%
print(f"p-value = {stats.ttest_1samp(np.array([202, 203, 199, 197, 195, 201, 200, 204, 194, 190]), 200).pvalue}")
# Out:
# p-value = 0.31456660352472854

# %% [markdown]
# $ Вывод:\ p-value > \alpha,=>\ статистически\ значимых\ различий\ нет.\ Нет\ оснований\ отвергнуть\ нулевую\ гипотезу.$
